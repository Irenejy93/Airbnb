# %%
#What kind of cleaning steps did you perform?
# identify and substitde all null value using 
#How did you deal with missing values, if any?
#-if they are numbers or 
#Were there outliers, and how did you handle them?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import datetime

# %%
test = pd.read_csv('test_users.csv')
train = pd.read_csv('train_users_2.csv')

# %%
test['gender'] = test['gender'].replace('-unknown-', np.nan)

# %%
test['gender'].astype(str)
# Out:
# 0        FEMALE
# 1           nan
# 2           nan
# 3           nan
# 4           nan
# 5        FEMALE
# 6          MALE
# 7           nan
# 8           nan
# 9           nan
# 10          nan
# 11       FEMALE
# 12         MALE
# 13          nan
# 14          nan
# 15       FEMALE
# 16          nan
# 17          nan
# 18       FEMALE
# 19         MALE
# 20       FEMALE
# 21          nan
# 22         MALE
# 23          nan
# 24          nan
# 25         MALE
# 26       FEMALE
# 27          nan
# 28          nan
# 29          nan
#           ...
# 62066       nan
# 62067    FEMALE
# 62068       nan
# 62069    FEMALE
# 62070    FEMALE
# 62071       nan
# 62072       nan
# 62073       nan
# 62074       nan
# 62075    FEMALE
# 62076      MALE
# 62077       nan
# 62078       nan
# 62079      MALE
# 62080       nan
# 62081    FEMALE
# 62082       nan
# 62083      MALE
# 62084      MALE
# 62085    FEMALE
# 62086       nan
# 62087      MALE
# 62088       nan
# 62089      MALE
# 62090       nan
# 62091       nan
# 62092       nan
# 62093       nan
# 62094       nan
# 62095    FEMALE
# Name: gender, Length: 62096, dtype: object

# %%
test = test.dropna(axis=1, how='all')

# %%
test.head()
# Out:
#            id date_account_created  timestamp_first_active  gender   age  \
# 0  5uwns89zht           2014-07-01          20140701000006  FEMALE  35.0
# 1  jtl0dijy2j           2014-07-01          20140701000051     NaN   NaN
# 2  xx0ulgorjt           2014-07-01          20140701000148     NaN   NaN
# 3  6c6puo6ix0           2014-07-01          20140701000215     NaN   NaN
# 4  czqhjk3yfe           2014-07-01          20140701000305     NaN   NaN
#
#   signup_method  signup_flow language affiliate_channel affiliate_provider  \
# 0      facebook            0       en            direct             direct
# 1         basic            0       en            direct             direct
# 2         basic            0       en            direct             direct
# 3         basic            0       en            direct             direct
# 4         basic            0       en            direct             direct
#
#   first_affiliate_tracked signup_app first_device_type  first_browser
# 0               untracked      Moweb            iPhone  Mobile Safari
# 1               untracked      Moweb            iPhone  Mobile Safari
# 2                  linked        Web   Windows Desktop         Chrome
# 3                  linked        Web   Windows Desktop             IE
# 4               untracked        Web       Mac Desktop         Safari

# %%
testclean = test.dropna().reset_index()

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213451 entries, 0 to 213450
# Data columns (total 16 columns):
# id                         213451 non-null object
# date_account_created       213451 non-null object
# timestamp_first_active     213451 non-null int64
# date_first_booking         88908 non-null object
# gender                     213451 non-null object
# age                        125461 non-null float64
# signup_method              213451 non-null object
# signup_flow                213451 non-null int64
# language                   213451 non-null object
# affiliate_channel          213451 non-null object
# affiliate_provider         213451 non-null object
# first_affiliate_tracked    207386 non-null object
# signup_app                 213451 non-null object
# first_device_type          213451 non-null object
# first_browser              213451 non-null object
# country_destination        213451 non-null object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 26.1+ MB

# %%
train['gender'] = train['gender'].astype(str)

# %%
train['gender'] = train['gender'].replace('-unknown-', np.nan)

# %%
train.head(20)
# Out:
#             id date_account_created  timestamp_first_active  \
# 0   gxn3p5htnn           2010-06-28          20090319043255
# 1   820tgsjxq7           2011-05-25          20090523174809
# 2   4ft3gnwmtx           2010-09-28          20090609231247
# 3   bjjt8pjhuk           2011-12-05          20091031060129
# 4   87mebub9p4           2010-09-14          20091208061105
# 5   osr2jwljor           2010-01-01          20100101215619
# 6   lsw9q7uk0j           2010-01-02          20100102012558
# 7   0d01nltbrs           2010-01-03          20100103191905
# 8   a1vcnhxeij           2010-01-04          20100104004211
# 9   6uh8zyj2gn           2010-01-04          20100104023758
# 10  yuuqmid2rp           2010-01-04          20100104194251
# 11  om1ss59ys8           2010-01-05          20100105051812
# 12  k6np330cm1           2010-01-05          20100105060859
# 13  dy3rgx56cu           2010-01-05          20100105083259
# 14  ju3h98ch3w           2010-01-07          20100107055820
# 15  v4d5rl22px           2010-01-07          20100107204555
# 16  2dwbwkx056           2010-01-07          20100107215125
# 17  frhre329au           2010-01-07          20100107224625
# 18  cxlg85pg1r           2010-01-08          20100108015641
# 19  gdka1q5ktd           2010-01-10          20100110010817
#
#    date_first_booking  gender   age signup_method  signup_flow language  \
# 0                 NaN     NaN   NaN      facebook            0       en
# 1                 NaN    MALE  38.0      facebook            0       en
# 2          2010-08-02  FEMALE  56.0         basic            3       en
# 3          2012-09-08  FEMALE  42.0      facebook            0       en
# 4          2010-02-18     NaN  41.0         basic            0       en
# 5          2010-01-02     NaN   NaN         basic            0       en
# 6          2010-01-05  FEMALE  46.0         basic            0       en
# 7          2010-01-13  FEMALE  47.0         basic            0       en
# 8          2010-07-29  FEMALE  50.0         basic            0       en
# 9          2010-01-04     NaN  46.0         basic            0       en
# 10         2010-01-06  FEMALE  36.0         basic            0       en
# 11                NaN  FEMALE  47.0         basic            0       en
# 12         2010-01-18     NaN   NaN         basic            0       en
# 13                NaN  FEMALE  37.0         basic            0       en
# 14                NaN  FEMALE  36.0         basic            0       en
# 15         2010-01-08  FEMALE  33.0         basic            0       en
# 16                NaN     NaN   NaN         basic            0       en
# 17         2010-01-09     NaN  31.0         basic            0       en
# 18                NaN     NaN   NaN         basic            0       en
# 19         2010-01-10  FEMALE  29.0         basic            0       en
#
#    affiliate_channel affiliate_provider first_affiliate_tracked signup_app  \
# 0             direct             direct               untracked        Web
# 1                seo             google               untracked        Web
# 2             direct             direct               untracked        Web
# 3             direct             direct               untracked        Web
# 4             direct             direct               untracked        Web
# 5              other              other                     omg        Web
# 6              other         craigslist               untracked        Web
# 7             direct             direct                     omg        Web
# 8              other         craigslist               untracked        Web
# 9              other         craigslist                     omg        Web
# 10             other         craigslist               untracked        Web
# 11             other         craigslist               untracked        Web
# 12            direct             direct                     NaN        Web
# 13             other         craigslist                  linked        Web
# 14             other         craigslist               untracked        Web
# 15            direct             direct               untracked        Web
# 16             other         craigslist                     NaN        Web
# 17             other         craigslist                     NaN        Web
# 18               seo           facebook                     NaN        Web
# 19            direct             direct               untracked        Web
#
#    first_device_type  first_browser country_destination
# 0        Mac Desktop         Chrome                 NDF
# 1        Mac Desktop         Chrome                 NDF
# 2    Windows Desktop             IE                  US
# 3        Mac Desktop        Firefox               other
# 4        Mac Desktop         Chrome                  US
# 5        Mac Desktop         Chrome                  US
# 6        Mac Desktop         Safari                  US
# 7        Mac Desktop         Safari                  US
# 8        Mac Desktop         Safari                  US
# 9        Mac Desktop        Firefox                  US
# 10       Mac Desktop        Firefox                  US
# 11            iPhone      -unknown-                 NDF
# 12     Other/Unknown      -unknown-                  FR
# 13       Mac Desktop        Firefox                 NDF
# 14            iPhone  Mobile Safari                 NDF
# 15   Windows Desktop         Chrome                  CA
# 16     Other/Unknown      -unknown-                 NDF
# 17     Other/Unknown      -unknown-                  US
# 18     Other/Unknown      -unknown-                 NDF
# 19       Mac Desktop         Chrome                  FR

# %%
cleantrain = train.dropna().reset_index()

# %%
cleantrain.head()
# Out:
#    index          id date_account_created  timestamp_first_active  \
# 0      2  4ft3gnwmtx           2010-09-28          20090609231247
# 1      3  bjjt8pjhuk           2011-12-05          20091031060129
# 2      6  lsw9q7uk0j           2010-01-02          20100102012558
# 3      7  0d01nltbrs           2010-01-03          20100103191905
# 4      8  a1vcnhxeij           2010-01-04          20100104004211
#
#   date_first_booking  gender   age signup_method  signup_flow language  \
# 0         2010-08-02  FEMALE  56.0         basic            3       en
# 1         2012-09-08  FEMALE  42.0      facebook            0       en
# 2         2010-01-05  FEMALE  46.0         basic            0       en
# 3         2010-01-13  FEMALE  47.0         basic            0       en
# 4         2010-07-29  FEMALE  50.0         basic            0       en
#
#   affiliate_channel affiliate_provider first_affiliate_tracked signup_app  \
# 0            direct             direct               untracked        Web
# 1            direct             direct               untracked        Web
# 2             other         craigslist               untracked        Web
# 3            direct             direct                     omg        Web
# 4             other         craigslist               untracked        Web
#
#   first_device_type first_browser country_destination
# 0   Windows Desktop            IE                  US
# 1       Mac Desktop       Firefox               other
# 2       Mac Desktop        Safari                  US
# 3       Mac Desktop        Safari                  US
# 4       Mac Desktop        Safari                  US

# %%
df = pd.concat((testclean, cleantrain), axis=0, ignore_index=True, sort=False)

# %%
df['age'].fillna(df['age'].mean(), inplace=True)

# %%
df.loc[df.age > 95, 'age'] = np.nan
df.loc[df.age < 18, 'age'] = np.nan

# %%
df['gender'].unique()
# Out:
# array(['FEMALE', 'MALE', 'OTHER'], dtype=object)

# %%
df['gender'].value_counts().plot(kind='bar')
# There is trend that female is more likely to register than male. However, there is significant amount of male also registered

# %%
df['country_destination'].value_counts().plot(kind='bar')
# The 1st country destination is US. 2nd is other and 3rd is France.

# %%
sns.catplot('country_destination', hue='gender', kind='count', data=df)
# In most of the countries female are more likely to register. 
# however, in other countries, male are more likely choose as destination.
# Therefore, there might be relationship between gender and destination selection.

# %%
sns.distplot(df.age.dropna())
# According to this bar plot, between age 25 to 40 has highest number of the people use airbnb.
# Out:
# /Users/irene/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.stripplot(x='country_destination', y='age', data=df, jitter=True)
# In US, most of the age range have used Airbnb. However, other countries and other destination is less likely to chosen by age above 70s and 80s
#since age is not constant in selecting destination, there might be relationship between age and destination.

# %%
df.signup_method.unique()
# Out:
# array(['facebook', 'basic', 'google', 'weibo'], dtype=object)

# %%
df['signup_method'].value_counts().plot(kind='bar')
# facebook and basic method is most popular method of signup

# %%
sns.catplot('country_destination', hue='signup_method', kind='count', data=df)

# %%
df['first_device_type'].value_counts().plot(kind='bar')
# Most of the users used desktop to register. Among the desktop, I can tell the Mac desktop is more likely to be used than Window desktop.

# %%
sns.catplot('country_destination', hue='first_device_type', kind='count', data=df)

# %%
df['signup_app'].value_counts().plot(kind='bar')

# %%
df['first_browser'].value_counts().plot(kind='bar')
# Among the lot of the browsers, chrome

# %%
df['language'].value_counts().plot(kind='bar')
# Since the data is collected in US, the language used is english and it seems

# %%
lan = df['language'].replace('en', np.nan)
lan.dropna()
lan.value_counts().plot(kind='bar')

# %%
df['affiliate_channel'].value_counts().plot(kind='bar')

# %%
df['affiliate_provider'].value_counts().plot(kind='bar')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84007 entries, 0 to 84006
# Data columns (total 17 columns):
# index                      84007 non-null int64
# id                         84007 non-null object
# date_account_created       84007 non-null datetime64[ns]
# timestamp_first_active     84007 non-null int64
# gender                     84007 non-null object
# age                        82897 non-null float64
# signup_method              84007 non-null object
# signup_flow                84007 non-null int64
# language                   84007 non-null object
# affiliate_channel          84007 non-null object
# affiliate_provider         84007 non-null object
# first_affiliate_tracked    84007 non-null object
# signup_app                 84007 non-null object
# first_device_type          84007 non-null object
# first_browser              84007 non-null object
# date_first_booking         56192 non-null object
# country_destination        56192 non-null object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(12)
# memory usage: 10.9+ MB

# %%
df['date_account_created'] = pd.to_datetime(df['date_account_created'])
df['date_account_created'].value_counts().plot()
plt.xlabel('Year')
plt.title('Account Created Date')
sns.despine()
# There are increase trend of creating the account as time goes and there was great increase in 2014

# %%
age = pd.read_csv('age_gender_bkts.csv')

# %%
age.groupby(age['country_destination'])

# %%
age = age.set_index(['country_destination'])

# %%
age.head()
# Out:
#                     age_bucket gender  population_in_thousands    year
# country_destination
# AU                        100+   male                      1.0  2015.0
# AU                       95-99   male                      9.0  2015.0
# AU                       90-94   male                     47.0  2015.0
# AU                       85-89   male                    118.0  2015.0
# AU                       80-84   male                    199.0  2015.0

# %%
session = pd.read_csv('sessions.csv')

# %%
session.head(10)
# Out:
#       user_id          action action_type            action_detail  \
# 0  d1mm9tcy42          lookup         NaN                      NaN
# 1  d1mm9tcy42  search_results       click      view_search_results
# 2  d1mm9tcy42          lookup         NaN                      NaN
# 3  d1mm9tcy42  search_results       click      view_search_results
# 4  d1mm9tcy42          lookup         NaN                      NaN
# 5  d1mm9tcy42  search_results       click      view_search_results
# 6  d1mm9tcy42          lookup         NaN                      NaN
# 7  d1mm9tcy42     personalize        data  wishlist_content_update
# 8  d1mm9tcy42           index        view      view_search_results
# 9  d1mm9tcy42          lookup         NaN                      NaN
#
#        device_type  secs_elapsed
# 0  Windows Desktop         319.0
# 1  Windows Desktop       67753.0
# 2  Windows Desktop         301.0
# 3  Windows Desktop       22141.0
# 4  Windows Desktop         435.0
# 5  Windows Desktop        7703.0
# 6  Windows Desktop         115.0
# 7  Windows Desktop         831.0
# 8  Windows Desktop       20842.0
# 9  Windows Desktop         683.0

# %%
session.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10567737 entries, 0 to 10567736
# Data columns (total 6 columns):
# user_id          object
# action           object
# action_type      object
# action_detail    object
# device_type      object
# secs_elapsed     float64
# dtypes: float64(1), object(5)
# memory usage: 483.8+ MB

# %%
session.action_detail.unique()
# Out:
# array([nan, 'view_search_results', 'wishlist_content_update',
#        'similar_listings', 'change_trip_characteristics', 'p3',
#        'header_userpic', 'contact_host', 'message_post', 'dashboard',
#        'create_user', 'confirm_email_link', 'user_profile_content_update',
#        'user_profile', 'pending', 'p5', 'create_phone_numbers',
#        'cancellation_policies', 'user_wishlists',
#        'change_contact_host_dates', 'wishlist', 'message_thread',
#        'request_new_confirm_email', 'send_message', 'your_trips',
#        'login_page', 'login', 'login_modal', 'toggle_archived_thread',
#        'p1', 'profile_verifications', 'edit_profile', 'oauth_login',
#        'post_checkout_action', 'account_notification_settings',
#        'update_user_profile', 'oauth_response', 'signup_modal',
#        'signup_login_page', 'at_checkpoint', 'manage_listing',
#        'create_listing', 'your_listings', 'profile_references',
#        'list_your_space', 'popular_wishlists', 'listing_reviews_page',
#        'apply_coupon', 'user_tax_forms', 'account_payout_preferences',
#        'guest_itinerary', 'guest_receipt', 'account_privacy_settings',
#        'lookup_message_thread', 'friends_wishlists', 'host_guarantee',
#        'delete_phone_numbers', 'account_transaction_history',
#        'set_password', 'guest_cancellation', 'change_or_alter',
#        'your_reservations', 'terms_and_privacy', 'airbnb_picks_wishlists',
#        'toggle_starred_thread', 'email_wishlist', 'email_wishlist_button',
#        'wishlist_note', 'calculate_worth', 'place_worth',
#        'change_password', 'alteration_field', 'previous_trips',
#        'update_listing', 'update_listing_description', 'user_reviews',
#        'update_user', 'notifications', 'user_social_connections',
#        'unavailable_dates', 'reservations', 'listing_reviews',
#        'user_listings', 'signup', 'message_inbox', 'trip_availability',
#        'payment_instruments', 'admin_templates', 'host_home',
#        'translations', 'forgot_password', 'homepage',
#        'remove_dashboard_alert', 'user_friend_recommendations',
#        'confirm_email', 'host_respond', 'booking',
#        'respond_to_alteration_request', 'alteration_request',
#        'create_alteration_request', 'delete_listing', 'set_password_page',
#        'delete_listing_description', 'translate_listing_reviews',
#        'book_it', 'instant_book', 'request_to_book', 'complete_booking',
#        'change_availability', 'special_offer_field',
#        'listing_recommendations', 'view_listing', 'listing_descriptions',
#        'user_languages', 'p4', 'message_to_host_focus',
#        'cancellation_policy_click', 'message_to_host_change',
#        'read_policy_click', 'phone_verification_success',
#        'p4_refund_policy_terms', 'apply_coupon_error',
#        'apply_coupon_click', 'coupon_field_focus', 'coupon_code_click',
#        'p4_terms', 'apply_coupon_click_success', 'tos_2014',
#        'view_reservations', 'view_locations', 'modify_users',
#        'view_security_checks', 'phone_numbers', 'profile_reviews',
#        'modify_reservations', 'view_resolutions',
#        'account_payment_methods', 'create_payment_instrument',
#        'set_default_payment_instrument', 'delete_payment_instrument',
#        'photos', 'click_reviews', 'move_map', 'share',
#        'cancellation_policy', 'click_about_host', 'click_amenities',
#        'host_refund_guest', 'host_respond_page', 'view_user_real_names',
#        'view_identity_verifications', 'view_ghosting_reasons',
#        'view_ghostings', 'host_standard_suspension',
#        'deactivate_user_account'], dtype=object)

# %%
session['action'] = session['action'].replace('-unknown-', np.nan)
session['action_type'] = session['action_type'].replace('-unknown-', np.nan)
session['action_detail'] = session['action_detail'].replace('-unknown-', np.nan)
session['device_type'] = session['device_type'].replace('-unknown-', np.nan)

# %%
session.dropna()
# Out:
#              user_id                 action action_type  \
# 1         d1mm9tcy42         search_results       click
# 3         d1mm9tcy42         search_results       click
# 5         d1mm9tcy42         search_results       click
# 7         d1mm9tcy42            personalize        data
# 8         d1mm9tcy42                  index        view
# 10        d1mm9tcy42         search_results       click
# 12        d1mm9tcy42            personalize        data
# 13        d1mm9tcy42                  index        view
# 14        d1mm9tcy42       similar_listings        data
# 15        d1mm9tcy42  ajax_refresh_subtotal       click
# 16        d1mm9tcy42       similar_listings        data
# 17        d1mm9tcy42  ajax_refresh_subtotal       click
# 19        d1mm9tcy42            personalize        data
# 20        d1mm9tcy42                   show        view
# 22        d1mm9tcy42         search_results       click
# 24        d1mm9tcy42         search_results       click
# 25        d1mm9tcy42            personalize        data
# 27        d1mm9tcy42                  index        view
# 29        d1mm9tcy42            personalize        data
# 30        d1mm9tcy42                   show        view
# 31        d1mm9tcy42  ajax_refresh_subtotal       click
# 33        d1mm9tcy42            personalize        data
# 34        d1mm9tcy42                   show        view
# 35        d1mm9tcy42  ajax_refresh_subtotal       click
# 37        d1mm9tcy42            personalize        data
# 38        d1mm9tcy42                   show        view
# 39        d1mm9tcy42  ajax_refresh_subtotal       click
# 41        d1mm9tcy42            personalize        data
# 42        d1mm9tcy42         header_userpic        data
# 43        d1mm9tcy42                   show        view
# ...              ...                    ...         ...
# 10567699  fa6260ziny       similar_listings        data
# 10567700  fa6260ziny   travel_plans_current        view
# 10567701  fa6260ziny                  index        view
# 10567702  fa6260ziny                  index        view
# 10567703  fa6260ziny            personalize        data
# 10567704  fa6260ziny         header_userpic        data
# 10567705  fa6260ziny            personalize        data
# 10567707  87k0fy4ugm                 update      submit
# 10567709  87k0fy4ugm            personalize        data
# 10567710  87k0fy4ugm         header_userpic        data
# 10567712  87k0fy4ugm                   show        view
# 10567713  87k0fy4ugm         header_userpic        data
# 10567714  87k0fy4ugm            personalize        data
# 10567715  87k0fy4ugm  ajax_refresh_subtotal       click
# 10567716  87k0fy4ugm       similar_listings        data
# 10567717  87k0fy4ugm                  index        view
# 10567718  87k0fy4ugm          confirm_email       click
# 10567719  87k0fy4ugm           authenticate      submit
# 10567720  87k0fy4ugm              dashboard        view
# 10567721  9uqfg8txu3                   show        view
# 10567722  9uqfg8txu3                 update      submit
# 10567723  9uqfg8txu3                   edit        view
# 10567725  9uqfg8txu3                 create      submit
# 10567728  9uqfg8txu3                 create      submit
# 10567729  9uqfg8txu3         header_userpic        data
# 10567730  9uqfg8txu3                   edit        view
# 10567731  9uqfg8txu3                   edit        view
# 10567732  9uqfg8txu3              dashboard        view
# 10567733  9uqfg8txu3                   edit        view
# 10567736  9uqfg8txu3       show_personalize        data
#
#                         action_detail      device_type  secs_elapsed
# 1                 view_search_results  Windows Desktop       67753.0
# 3                 view_search_results  Windows Desktop       22141.0
# 5                 view_search_results  Windows Desktop        7703.0
# 7             wishlist_content_update  Windows Desktop         831.0
# 8                 view_search_results  Windows Desktop       20842.0
# 10                view_search_results  Windows Desktop       59274.0
# 12            wishlist_content_update  Windows Desktop        1399.0
# 13                view_search_results  Windows Desktop       74886.0
# 14                   similar_listings  Windows Desktop         255.0
# 15        change_trip_characteristics  Windows Desktop        8134.0
# 16                   similar_listings  Windows Desktop         183.0
# 17        change_trip_characteristics  Windows Desktop      175570.0
# 19            wishlist_content_update  Windows Desktop        1535.0
# 20                                 p3  Windows Desktop       83251.0
# 22                view_search_results  Windows Desktop        2488.0
# 24                view_search_results  Windows Desktop       10053.0
# 25            wishlist_content_update  Windows Desktop          50.0
# 27                view_search_results  Windows Desktop       82263.0
# 29            wishlist_content_update  Windows Desktop         673.0
# 30                                 p3  Windows Desktop        2959.0
# 31        change_trip_characteristics  Windows Desktop         982.0
# 33            wishlist_content_update  Windows Desktop         808.0
# 34                                 p3  Windows Desktop        6417.0
# 35        change_trip_characteristics  Windows Desktop        1013.0
# 37            wishlist_content_update  Windows Desktop        1281.0
# 38                                 p3  Windows Desktop       10401.0
# 39        change_trip_characteristics  Windows Desktop         427.0
# 41            wishlist_content_update  Windows Desktop          75.0
# 42                     header_userpic  Windows Desktop        1063.0
# 43                                 p3  Windows Desktop      189200.0
# ...                               ...              ...           ...
# 10567699             similar_listings  Windows Desktop        4752.0
# 10567700                   your_trips  Windows Desktop          44.0
# 10567701          view_search_results  Windows Desktop        8448.0
# 10567702          view_search_results  Windows Desktop         595.0
# 10567703      wishlist_content_update  Windows Desktop        1802.0
# 10567704               header_userpic  Windows Desktop        1427.0
# 10567705      wishlist_content_update  Windows Desktop          69.0
# 10567707               update_listing      Mac Desktop        3490.0
# 10567709      wishlist_content_update      Mac Desktop         189.0
# 10567710               header_userpic      Mac Desktop         698.0
# 10567712                           p3      Mac Desktop       21062.0
# 10567713               header_userpic           iPhone         897.0
# 10567714      wishlist_content_update      Mac Desktop          17.0
# 10567715  change_trip_characteristics      Mac Desktop         602.0
# 10567716             similar_listings      Mac Desktop         257.0
# 10567717          view_search_results      Mac Desktop       14711.0
# 10567718           confirm_email_link           iPhone      253296.0
# 10567719                        login           iPhone       26581.0
# 10567720                    dashboard           iPhone        2694.0
# 10567721                 user_profile  Windows Desktop         447.0
# 10567722          update_user_profile  Windows Desktop      124020.0
# 10567723                 edit_profile  Windows Desktop       22920.0
# 10567725         create_phone_numbers  Windows Desktop       57382.0
# 10567728         create_phone_numbers  Windows Desktop       27206.0
# 10567729               header_userpic  Windows Desktop        1939.0
# 10567730                 edit_profile  Windows Desktop     1752436.0
# 10567731                 edit_profile  Windows Desktop       15875.0
# 10567732                    dashboard  Windows Desktop         556.0
# 10567733                 edit_profile  Windows Desktop        6624.0
# 10567736  user_profile_content_update  Windows Desktop        1221.0
#
# [8072496 rows x 6 columns]

# %%
session.loc[(session['action_detail'] == 'complete_booking')]
# Out:
#              user_id action action_type     action_detail    device_type  \
# 1319663   jzdix1ilgd  click       click  complete_booking         iPhone
# 1332250   7vxv10hv5z  click       click  complete_booking         iPhone
# 1415624   853xrxhajm  click       click  complete_booking         iPhone
# 1415811   853xrxhajm  click       click  complete_booking         iPhone
# 1454021   i35xbvtu4s  click       click  complete_booking         iPhone
# 1454225   i35xbvtu4s  click       click  complete_booking         iPhone
# 1549732   j6fw0jxg47  click       click  complete_booking         iPhone
# 1588968   99jtu8071w  click       click  complete_booking         iPhone
# 1588990   99jtu8071w  click       click  complete_booking         iPhone
# 1771705   6kyxp4jx74  click       click  complete_booking         iPhone
# 1771878   6kyxp4jx74  click       click  complete_booking         iPhone
# 1771887   6kyxp4jx74  click       click  complete_booking         iPhone
# 1772180   6kyxp4jx74  click       click  complete_booking         iPhone
# 1772630   6kyxp4jx74  click       click  complete_booking         iPhone
# 1772642   6kyxp4jx74  click       click  complete_booking         iPhone
# 1968376   7ydq98xcvr  click       click  complete_booking         iPhone
# 1968377   7ydq98xcvr  click       click  complete_booking         iPhone
# 1992845   8c44zprarl  click       click  complete_booking         iPhone
# 2114104   4b4p7ytjlp  click       click  complete_booking         iPhone
# 2223979   63hdlkrj48  click       click  complete_booking         iPhone
# 2224492   yup1bxy271  click       click  complete_booking         iPhone
# 2224544   yup1bxy271  click       click  complete_booking         iPhone
# 3087716   wxl5lnf1us  click       click  complete_booking         iPhone
# 3087768   wxl5lnf1us  click       click  complete_booking         iPhone
# 3187216   ucg6eq5g1d  click       click  complete_booking         iPhone
# 3228389   okj072d3tt  click       click  complete_booking         iPhone
# 3635949   z0sld86nn4  click       click  complete_booking         iPhone
# 3636132   z0sld86nn4  click       click  complete_booking         iPhone
# 3681150   yw264fyfcb  click       click  complete_booking         iPhone
# 3681151   yw264fyfcb  click       click  complete_booking         iPhone
# ...              ...    ...         ...               ...            ...
# 5147301   huzu2ymqfl  click       click  complete_booking         iPhone
# 5172908   31j7sf5nas  click       click  complete_booking         iPhone
# 5341398   epmlht38od  click       click  complete_booking         iPhone
# 5494739   icsnlb6dpd  click       click  complete_booking         iPhone
# 6499153   upkr1q0hx9  click       click  complete_booking         iPhone
# 6648009   mjbl6rrj52  click       click  complete_booking         iPhone
# 6684247   3z8kvlahg0  click       click  complete_booking         iPhone
# 6705875   6bevuhqoz9  click       click  complete_booking         iPhone
# 6705980   6bevuhqoz9  click       click  complete_booking    iPad Tablet
# 6986674   epzq8rvf2m  click       click  complete_booking    iPad Tablet
# 6986723   epzq8rvf2m  click       click  complete_booking    iPad Tablet
# 6986980   epzq8rvf2m  click       click  complete_booking    iPad Tablet
# 8026804   5ursq3f4kf  click       click  complete_booking         iPhone
# 8181118   qc1fzmn2mb  click       click  complete_booking         iPhone
# 8181119   qc1fzmn2mb  click       click  complete_booking         iPhone
# 8592286   1ztjbqgko5  click       click  complete_booking         iPhone
# 9084135   kz983n827d  click       click  complete_booking    iPad Tablet
# 9481365   4n4yootff6  click       click  complete_booking         iPhone
# 9481381   4n4yootff6  click       click  complete_booking         iPhone
# 9491526   bskpfcg6xx  click       click  complete_booking         iPhone
# 9501792   qy3we9o4hd  click       click  complete_booking  Android Phone
# 9621240   kojs2gtp6v  click       click  complete_booking         iPhone
# 9730249   i5v9eedtzf  click       click  complete_booking  Android Phone
# 9997149   086fzy4hbm  click       click  complete_booking         iPhone
# 10259559  ux0xxqv0ti  click       click  complete_booking  Android Phone
# 10259574  ux0xxqv0ti  click       click  complete_booking  Android Phone
# 10388853  uu77pt16jg  click       click  complete_booking  Android Phone
# 10410211  egx4aad9yo  click       click  complete_booking         iPhone
# 10410383  egx4aad9yo  click       click  complete_booking         iPhone
# 10410408  egx4aad9yo  click       click  complete_booking         iPhone
#
#           secs_elapsed
# 1319663       934205.0
# 1332250        97459.0
# 1415624        32874.0
# 1415811        37465.0
# 1454021            1.0
# 1454225        14116.0
# 1549732       627249.0
# 1588968        57144.0
# 1588990         7133.0
# 1771705            0.0
# 1771878         3630.0
# 1771887        32163.0
# 1772180        28247.0
# 1772630        12154.0
# 1772642        26210.0
# 1968376            2.0
# 1968377       418084.0
# 1992845        32001.0
# 2114104         2189.0
# 2223979        10275.0
# 2224492        56800.0
# 2224544         4444.0
# 3087716            0.0
# 3087768         3639.0
# 3187216        56237.0
# 3228389          800.0
# 3635949         1496.0
# 3636132        57755.0
# 3681150        18939.0
# 3681151            0.0
# ...                ...
# 5147301         1209.0
# 5172908          232.0
# 5341398        45233.0
# 5494739        25571.0
# 6499153        21465.0
# 6648009         4445.0
# 6684247        12257.0
# 6705875         6359.0
# 6705980         2204.0
# 6986674            0.0
# 6986723        17827.0
# 6986980         8487.0
# 8026804        93825.0
# 8181118            0.0
# 8181119         1215.0
# 8592286         8385.0
# 9084135         5782.0
# 9481365         9221.0
# 9481381         3848.0
# 9491526        42703.0
# 9501792        36251.0
# 9621240         9913.0
# 9730249            0.0
# 9997149        45979.0
# 10259559           1.0
# 10259574           1.0
# 10388853           0.0
# 10410211       13044.0
# 10410383       27269.0
# 10410408       37916.0
#
# [75 rows x 6 columns]
